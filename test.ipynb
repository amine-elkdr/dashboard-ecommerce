# %%
from src.data_loader import load_data

df = load_data()
print(df.shape)
print(df.head())
# Out:
# (397884, 10)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue    Month
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30  2010-12
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34  2010-12
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00  2010-12
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34  2010-12
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34  2010-12

# %%
from src.metrics import get_kpis, get_revenue_by_month, get_top_products, get_top_countries

print(get_kpis(df))
print(get_revenue_by_month(df))
print(get_top_products(df))
print(get_top_countries(df))
# Out:
# {'total_revenue': np.float64(8911407.9), 'total_orders': 18532, 'avg_basket': np.float64(480.87), 'total_customers': 4338}
#       Month      Revenue
# 0   2010-12   572713.890
# 1   2011-01   569445.040
# 2   2011-02   447137.350
# 3   2011-03   595500.760
# 4   2011-04   469200.361
# 5   2011-05   678594.560
# 6   2011-06   661213.690
# 7   2011-07   600091.011
# 8   2011-08   645343.900
# 9   2011-09   952838.382
# 10  2011-10  1039318.790
# 11  2011-11  1161817.380
# 12  2011-12   518192.790
#                           Description    Revenue
# 0         PAPER CRAFT , LITTLE BIRDIE  168469.60
# 1            REGENCY CAKESTAND 3 TIER  142592.95
# 2  WHITE HANGING HEART T-LIGHT HOLDER  100448.15
# 3             JUMBO BAG RED RETROSPOT   85220.78
# 4      MEDIUM CERAMIC TOP STORAGE JAR   81416.73
# 5                             POSTAGE   77803.96
# 6                       PARTY BUNTING   68844.33
# 7       ASSORTED COLOUR BIRD ORNAMENT   56580.34
# ...

# %%
from src.metrics import *
from src.charts import *

# KPIs
print(get_kpis(df))
print(get_retention(df))

# Graphiques
chart_revenue_by_month(get_revenue_by_month(df)).show()
chart_top_products(get_top_products(df)).show()
chart_top_countries(get_top_countries(df)).show()
chart_world_map(get_top_countries(df, n=50)).show()
chart_retention(get_retention(df)).show()
chart_orders_by_month(get_orders_by_month(df)).show()
chart_avg_basket_by_month(get_avg_basket_by_month(df)).show()
chart_top_customers(get_top_customers(df)).show()
chart_revenue_by_weekday(get_revenue_by_weekday(df)).show()
chart_heatmap(df).show()
chart_scatter(df).show()
# Out:
# {'total_revenue': np.float64(8911407.9), 'total_orders': 18532, 'avg_basket': np.float64(480.87), 'total_customers': 4338}
# {'new_customers': 1493, 'returning_customers': 2845}
